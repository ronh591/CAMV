# %% [markdown]
# <a href="https://colab.research.google.com/github/ronh591/CAMV/blob/master/use_python_in_google_colabs_to_print_out_a_concept_sketch_of_the_solar_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Concept Sketch of the Solar System in Python using Google Colab
#
# Here's a Python code snippet you can run in Google Colab to generate a basic concept sketch of the Solar System:

# %%
from matplotlib import pyplot as plt

# Define the Sun's properties
sun_radius = 50  # Adjust this for size preference

# Define planet data (orbital radius, size relative to Sun)
planets = {
    "Mercury": (0.39, 0.038),
    "Venus": (0.72, 0.095),
    "Earth": (1.0, 0.1),
    "Mars": (1.52, 0.053),
    "Jupiter": (5.2, 1.12),
    "Saturn": (9.5, 0.95),
    "Uranus": (19.2, 0.38),
    "Neptune": (30.1, 0.34),
}

# Create the figure and background
fig, ax = plt.subplots()
ax.set_aspect("equal")  # Ensures circular planets
ax.set_xlabel("Distance from Sun (AU)")
ax.set_ylabel("Orbital Plane")
ax.set_xlim(-sun_radius - sun_radius/5, sun_radius + sun_radius/5)
ax.set_ylim(-sun_radius - sun_radius/5, sun_radius + sun_radius/5)

# Draw the Sun
circle1 = plt.Circle((0, 0), sun_radius, color="yellow")
ax.add_patch(circle1)

# Draw planet orbits
for planet, data in planets.items():
    orbit_radius = data[0] * sun_radius  # Scale orbital radius based on Sun's size
    circle2 = plt.Circle((0, 0), orbit_radius, color="gray", alpha=0.3, linewidth=0.5)
    ax.add_patch(circle2)

# Draw planets
for planet, data in planets.items():
    planet_radius = data[1] * sun_radius  # Scale planet size based on Sun's size
    circle3 = plt.Circle((orbit_radius * np.cos(np.radians(i)), orbit_radius * np.sin(np.radians(i))), planet_radius, color="orange")
    ax.add_patch(circle3)
    plt.annotate(planet, (orbit_radius * np.cos(np.radians(i)) + planet_radius, orbit_radius * np.sin(np.radians(i)) + planet_radius), fontsize=8)

# Customize and display the plot
plt.title("Concept Sketch of the Solar System")
plt.xticks([])
plt.yticks([])
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5ee6c3bae874> in <cell line: 37>()
#      37 for planet, data in planets.items():
#      38     planet_radius = data[1] * sun_radius  # Scale planet size based on Sun's size
# ---> 39     circle3 = plt.Circle((orbit_radius * np.cos(np.radians(i)), orbit_radius * np.sin(np.radians(i))), planet_radius, color="orange")
#      40     ax.add_patch(circle3)
#      41     plt.annotate(planet, (orbit_radius * np.cos(np.radians(i)) + planet_radius, orbit_radius * np.sin(np.radians(i)) + planet_radius), fontsize=8)
#
# NameError: name 'np' is not defined

# %% [markdown]
# This code defines the Sun's size and the relative sizes and orbital radii of the eight main planets. It then creates a matplotlib figure and plots the Sun as a circle. Orbits are drawn as faint gray circles, and planets are drawn as colored circles positioned along their respective orbits.
#
# The script also annotates each planet with its name for easy identification. Feel free to adjust the Sun's size, planet sizes, colors, and orbit line styles to customize your concept sketch.
#
# **Adding More Details:**
#
# To enhance your concept sketch, consider adding:
#
# * **Planet moons:** Research the major moons of each planet and plot them as smaller circles orbiting their respective planets.
# * **Dwarf planets:** Include Pluto and other dwarf planets beyond Neptune's orbit.
# * **Asteroid belt:** Draw a faint ring between Mars and Jupiter to represent the asteroid belt.
# * **Comet trails:** Add faint, curved lines extending from the outer Solar System to depict cometary orbits.
#
# Remember, this is just a starting point. Experiment with different elements and styles to create a unique and informative concept sketch of the Solar System that reflects your understanding of our cosmic neighborhood.
#
# I hope this helps! Feel free to ask if you have any questions about the code or the Solar System.
